# %%
import pandas as pd
customers_df = pd.read_csv( "customers.csv" )

# %%
customers_df.head()
# Out:
#     income    age
# 0  41100.0  48.75
# 1  54100.0  28.10
# 2  47800.0  46.75
# 3  19100.0  40.25
# 4  18200.0  35.80

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
sn.lmplot(x="age", y="income", data=customers_df, fit_reg=False, height=4)
plt.title("Customer Segments Based on Income and Age")
# Out:
# Text(0.5, 1.0, 'Customer Segments Based on Income and Age')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_customers_df = scaler.fit_transform( 
    customers_df[["age", "income"]] )

scaled_customers_df[0:5]
# Out:
# array([[ 1.3701637 ,  0.09718548],
#        [-1.3791283 ,  0.90602749],
#        [ 1.10388844,  0.51405021],
#        [ 0.23849387, -1.27162408],
#        [-0.35396857, -1.32762083]])

# %%
from sklearn.cluster import KMeans

clusters_new = KMeans( 3, random_state=42 )
clusters_new.fit( scaled_customers_df )
customers_df["clusterid_new"] = clusters_new.labels_

# %%
markers = ['+', '^', '.']

sn.lmplot(x="age", y="income", 
          data=customers_df, 
          hue="clusterid_new", 
          fit_reg=False, 
          markers=markers,
          height=4)
plt.title("Customer segments created after normalization")
# Out:
# Text(0.5, 1.0, 'Customer segments created after normalization')

# %%
customers_df.groupby('clusterid_new')[['age', 'income']].agg(["mean"]).reset_index()
# Out:
#   clusterid_new        age        income
#                       mean          mean
# 0             0  46.627184  44308.737864
# 1             1  29.384000  55204.000000
# 2             2  39.140206  18321.649485

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_customers_df = scaler.fit_transform( 
    customers_df[["age", "income"]] )

scaled_customers_df[0:5]
# Out:
# array([[ 1.3701637 ,  0.09718548],
#        [-1.3791283 ,  0.90602749],
#        [ 1.10388844,  0.51405021],
#        [ 0.23849387, -1.27162408],
#        [-0.35396857, -1.32762083]])

# %%
from sklearn.cluster import KMeans

clusters_new = KMeans( 3, random_state=42 )
clusters_new.fit( scaled_customers_df )
customers_df["clusterid_new"] = clusters_new.labels_

# %%
markers = ['+','^','.']

sn.lmplot(x="age", y="income", 
          data=customers_df, 
          hue="clusterid_new", 
          fit_reg=False, 
          markers=markers,
          height=4)
plt.title("Customer segments created after normalization")
# Out:
# Text(0.5, 1.0, 'Customer segments created after normalization')
